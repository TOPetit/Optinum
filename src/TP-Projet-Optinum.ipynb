# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Année 2020-2021 - 2e année département Sciences du Numérique </h1>
# <h1> Noms: Ben Aim et Petit </h1>
# <h1> Prénoms: Gautier et Théo </h1>
# </center>

# %% [markdown]
# # Algorithme de Newton
# ## Implémentation
#
# 1. Coder l’algorithme de Newton local tel que décrit dans la section *Algorithme de Newton* (fichier `Algorithme_De_Newton.jl`)
#
# 2. Tester l’algorithme sur les fonctions $f_{1}$ , $f_{2}$ avec les points initiaux $x_{011}$ , $x_{012}$ (pour $f_{1}$ ) et $x_{021}$ , $x_{022}$ , $x_{023}$ (pour $f_{2}$ ) donnés en Annexe A.

# %%
# Afficher les points stationnaires + les valeurs des fonctions en ces points si possible




#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme de Newton
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters,time)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
	println("  * Temps d'execution : ", time, "s")
end


# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

x0 = sol_exacte
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)
x0 = -pi/2+0.5
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)
x0 = pi/2
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)


# Fonction f1
# -----------
f1(x) =  2*(x[1] + x[2] + x[3] - 3)^2 + (x[1] - x[2])^2 + (x[2] - x[3])^2
# la gradient de la fonction f0
grad_f1(x) = [ 2 * (3 * x[1] + x[2] + 2 * x[3] - 6)
               2 * (x[1] + 4 * x[2] + x[3] -6)
               2 * (2*x[1] + x[2] + 3 * x[3] - 6)]
# la hessienne de la fonction f0
hess_f1(x) = [6 2 4
              2 8 2
              4 2 6]
sol_exacte = [1; 1; 1]

x0 = [1; 0; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f1",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)

x0 = [10; 3; -2.2]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f1",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)


# Fonction f2
# -----------
f2(x) =  100*(x[2] - x[1]^2)^2 + (1 - x[1])^2
# la gradient de la fonction f0
grad_f2(x) = [2 * (200 * x[1]^3 -200 * x[1] * x[2] + x[1] - 1); 200 * (x[2] - x[1]^2)]
# la hessienne de la fonction f0

hess_f2(x) = [ (-400(x[2]-x[1]^2)+800*x[1]^2+2) (-400*x[1])
               (-400x[1])                       (200)]
sol_exacte = [1; 1]


x0 = [-1.2; 1]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f2",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)

x0 = [10; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f2",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)

x0 = [0; 2e-3 + 1e-12]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats("Newton","f2",x0,xmin,f_min,flag,sol_exacte,nb_iters,(t2-t1)/1e9)


#=
# Fonction f3 (fonction de test)
# -----------
f3(x) =  x[1]^2 + x[2]^3
# la gradient de la fonction f0
grad_f3(x) = [2*x[1]; 3*x[2]^2]
# la hessienne de la fonction f0
hess_f3(x) = [2 0; 0 6*x[2]]
sol_exacte = "inconnue"


x0 = [1.5; 1]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f3,grad_f3,hess_f3,x0,options)
my_afficher_resultats("Newton","f3",x0,xmin,f_min,flag,sol_exacte,nb_iters)
=#
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
#   * Temps d'execution : 0.0210605s
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.5707963267949088
#   * f(xsol) = -1.0
#   * nb_iters = 3
#   * flag = 2
#   * sol_exacte : -1.5707963267948966
#   * Temps d'execution : 0.0006239s
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = 1.5707963267948966
#   * f(xsol) = 1.0
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
#   * Temps d'execution : 0.000537999s
# ...

# %% [markdown]
# ## Interprétation
#
# Justifier
#
# 1. les résultats obtenus pour l'exemple $f_0$ ci-dessus;
#
# 2. que l’algorithme implémenté converge en une itération pour $f_{1}$;
#
# 3. que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.

# %% [markdown]
# ## Vos réponses?
# 1. Les deux premiers points nous fournissent une bonne approximation de la solution exacte. Le premier s'arrête car il a convergé, le second s'arrête car l'image par f des points evalués stagne. Quant au troisième point, il s'agit d'un maximum de f0, la tangente est horizontale, il y a stagnation de l'abscisse des points étudiés.
# 2. Pour le premier cas de f1 (x0 = [1; 1; 0]), la direction de newton en ce point nous emmène directement vers unpoint critique (qui est d'ailleurs minimum global car f1 est une forme quadratique et f1(1,1,1) = 0) en [1; 1; 1]. La norme du gradient en ce minimum est nulle, le programme a convergé en une seule itération.
# 3.

# %% [markdown]
# # Régions de confiance avec pas de cauchy
#
# ## Implémentation
#
# 1. Coder l'algorithme du pas de Cauchy d’un sous-problème de
# régions de confiance (fichier `Pas_De_Cauchy.jl`). Tester sur les quadratiques proposées en Annexe B.
#
# 2. Coder l'algorithme de régions de confiance (fichier `Regions_De_Confiance.jl`). Tester sur les problèmes de l’Annexe A.

# %%
# Vos tests


#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra, Markdown
                                           # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Pas_De_Cauchy.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme du Pas de Cauchy
function my_afficher_resultats(f, g, H, s, e)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : Pas de Cauchy appliqué à la quadratique ",f, ":\n",bold=true,color=:blue)
	println("  * g = ", g)
	println("  * H = ", H)
	println("  * s = ", s)
	println("  * e = ", e)
end

# Affichage les sorties de l'algorithme des régions de confiance
function my_afficher_resultats2(algo, nom_fct, point_init, xmin, fxmin, flag, nbiters, time)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de l'algorithme des régions de confiance (version ", algo, ") appliqué à ", nom_fct, ":\n",bold=true,color=:blue)
	println("  * Point initial x0 = ", point_init)
	println("  * Soltion trouvée xmin = ", xmin)
	println("  * Image de xmin par ", nom_fct, " = ", fxmin)
	println("  * Nombre d'itérations = ", nbiters)
	println("  * Flag = ", flag)
    println("  * Temps de calcul : ", time, "s")
end

#=
# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
x0 = 0
options = []

xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats2("Cauchy","f0",x0,xmin,f_min,flag,nb_iters)
=#


# Quadratique 1
# -----------
# Gradient
g1 = [0; 0]
# Hessienne
H1 = [7 0; 0 2]
# Rayon de la région de confiance
delta1 = 2

# Quadratique 2
# -----------
# Gradient
g2 = [6; 2]
# Hessienne
H2 = [7 0; 0 2]
# Rayon de la région de confiance
delta2 = 2

# Quadratique 3
# -----------
# Gradient
g3 = [-2; 1]
# Hessienne
H3 = [-2 0; 0 10]
# Rayon de la région de confiance
delta3 = 2

s1,e1 = Pas_De_Cauchy(g1, H1, delta1)
s2,e2 = Pas_De_Cauchy(g2, H2, delta2)
s3,e3 = Pas_De_Cauchy(g3, H3, delta3)
my_afficher_resultats("q1", g1, H1, s1, e1)
my_afficher_resultats("q2", g2, H2, s2, e2)
my_afficher_resultats("q3", g3, H3, s3, e3)



# Fonction f1
# -----------
f1(x) =  2*(x[1] + x[2] + x[3] - 3)^2 + (x[1] - x[2])^2 + (x[2] - x[3])^2
# la gradient de la fonction f0
grad_f1(x) = [ 2 * (3 * x[1] + x[2] + 2 * x[3] - 6)
               2 * (x[1] + 4 * x[2] + x[3] -6)
               2 * (2*x[1] + x[2] + 3 * x[3] - 6)]
# la hessienne de la fonction f0
hess_f1(x) = [6 2 4
              2 8 2
              4 2 6]
sol_exacte = [1; 1; 1]
options = []

x0 = [1; 0; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats2("Cauchy","f1",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [10; 3; -2.2]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats2("Cauchy","f1",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)


# Fonction f2
# -----------
f2(x) =  100*(x[2] - x[1]^2)^2 + (1 - x[1])^2
# la gradient de la fonction f0
grad_f2(x) = [2 * (200 * x[1]^3 -200 * x[1] * x[2] + x[1] - 1); 200 * (x[2] - x[1]^2)]
# la hessienne de la fonction f0

hess_f2(x) = [ (-400(x[2]-x[1]^2)+800*x[1]^2+2) (-400*x[1])
               (-400x[1])                       (200)]
sol_exacte = [1; 1]


x0 = [-1.2; 1]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("Cauchy","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [10; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("Cauchy","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [0; 2e-3 + 1e-12]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("Cauchy","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q1:
#   * g = [0, 0]
#   * H = [7 0; 0 2]
#   * s = [0.0, 0.0]
#   * e = 0
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q2:
#   * g = [6, 2]
#   * H = [7 0; 0 2]
#   * s = [-0.9230769230769234, -0.30769230769230776]
#   * e = -1
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q3:
#   * g = [-2, 1]
#   * H = [-2 0; 0 10]
#   * s = [1.7888543819998317, -0.8944271909999159]
#   * e = 1
# -------------------------------------------------------------------------
# Résultats de l'algorithme des régions de confiance (version Cauchy) appliqué à f1:
#   * Point initial x0 = [1, 0, 0]
#   * Soltion trouvée xmin = [1.000055887334988, 0.999992420017735, 0.9999289527004823]
# ...

# %% [markdown]
# ## Interprétation
#
# 1. Quelle relation lie la fonction test $f_1$ et son modèle de Taylor à l’ordre 2 ? Comparer alors les performances de Newton et RC-Pas de Cauchy sur cette fonction.
#
# 2. Le rayon initial de la région de confiance est un paramètre important dans l’analyse
# de la performance de l’algorithme. Sur quel(s) autre(s) paramètre(s) peut-on jouer
# pour essayer d’améliorer cette performance ? Étudier l’influence d’au moins deux de
# ces paramètres.

# %% [markdown]
# ## Vos réponses?
#
# 1. f1 est une fonction quadratique, on a donc une égallité entre f1 et sa quadratique. On remarque que l'algorithme de Newton est bien plus efficace que RC-Pas de Cauchy.
# 2. Mis à part le rayon de la région de confiance initial:
#
# a) On peut jouer sur les valeurs de eta1 et eta2. Prenons l'exemple suivant : on passe de (eta1 = 0.25; eta2 = 0.75) à (eta1 = 0.45; eta2 = 0.55). Déjà, on doit d'attendre à bien plus de mise à jour de la région de confiance, car l'intervalle [eta1;eta2] a été réduit. On va conclure beaucoup plus strictement entre une itération ratée et une itération très réussie. Sur les fonction données, on observe que l'algorithme converge plus vite pour f2 en faisant cette modification (en partant de [-1.2; 1.0], on fait maintenant 3x moins d'itérations).
#
# b) On peut jouer sur la valeur de gamma1, qui est utilisé pour diminuer le rayon de la région de confiance lorsqu'il n'est pas satisfaisant. Plus gamma1 est petit, plus la région de confiance diminuera rapidement. En passant de 0.25 à 0.75 par exemple, le rayon de la région de confiance augmente rapidement lorsqu'il es très satisfaisant (car gamma2 = 2), mais diminue très lentement sinon. Cela permet de ne pas pénaliser l'algorithme si une fois l'approximation de f par sa quadratique n'est pas bonne. On diminue le nombre d'itération avant stagnation du f sur les exemple de f2 ci-dessus.

# %% [markdown]
# # Régions de confiance avec gradient conjugué tronqué
#
# ## Implémentation
#
# 1. Implémenter l’algorithme du Gradient Conjugué Tronqué, en se basant sur le cours (fichier `Gradient_Conjugue_Tronque.jl`).
# On validera les résultats sur les fonctions de l’Annexe C.
#
# 2. Intégrer finalement l’algorithme du Gradient Conjugué Tronqué dans le code de
# régions de confiance, et appliquer ce code pour résoudre les exemples proposés en
# Annexe A.

# %%
# Vos tests

using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Gradient_Conjugue_Tronque.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme du gradient conjugué tronqué
function my_afficher_resultats(f, g, H, s)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : gradient conjugué tronqué appliqué à la quadratique ",f, ":\n",bold=true,color=:blue)
	println("  * g = ", g)
	println("  * H = ", H)
	println("  * s = ", s)
end

# Affichage les sorties de l'algorithme des régions de confiance
function my_afficher_resultats2(algo, nom_fct, point_init, xmin, fxmin, flag, nbiters, time)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de l'algorithme des régions de confiance (version ", algo, ") appliqué à ", nom_fct, ":\n",bold=true,color=:blue)
	println("  * Point initial x0 = ", point_init)
	println("  * Soltion trouvée xmin = ", xmin)
	println("  * Image de xmin par ", nom_fct, " = ", fxmin)
	println("  * Nombre d'itérations = ", nbiters)
	println("  * Flag = ", flag)
    println("  * Temps de calcul : ", time, "s")
end

# Quadratique 1
# -----------
# Gradient
g1 = [0; 0]
# Hessienne
H1 = [7 0; 0 2]
# Rayon de la région de confiance
delta1 = 1e-2

# Quadratique 2
# -----------
# Gradient
g2 = [6; 2]
# Hessienne
H2 = [7 0; 0 2]
# Rayon de la région de confiance
delta2 = 1e-2

# Quadratique 3
# -----------
# Gradient
g3 = [-2; 1]
# Hessienne
H3 = [-2 0; 0 10]
# Rayon de la région de confiance
delta3 = 1e-2

# Quadratique 4
# -----------
# Gradient
g4 = [0; 0]
# Hessienne
H4 = [-2 0; 0 10]
# Rayon de la région de confiance
delta4 = 1e-2

# Quadratique 5
# -----------
# Gradient
g5 = [2; 3]
# Hessienne
H5 = [4 6; 6 5]
# Rayon de la région de confiance
delta5 = 1e-2

# Quadratique 6
# -----------
# Gradient
g6 = [2; 0]
# Hessienne
H6 = [4 0; 0 -15]
# Rayon de la région de confiance
delta6 = 1e-2

options = []

s1 = Gradient_Conjugue_Tronque(g1, H1, options)
s2 = Gradient_Conjugue_Tronque(g2, H2, options)
s3 = Gradient_Conjugue_Tronque(g3, H3, options)
s4 = Gradient_Conjugue_Tronque(g4, H4, options)
s5 = Gradient_Conjugue_Tronque(g5, H5, options)
s6 = Gradient_Conjugue_Tronque(g6, H6, options)

my_afficher_resultats("q1", g1, H1, s1)
my_afficher_resultats("q2", g2, H2, s2)
my_afficher_resultats("q3", g3, H3, s3)
my_afficher_resultats("q4", g4, H4, s4)
my_afficher_resultats("q5", g5, H5, s5)
my_afficher_resultats("q6", g6, H6, s6)


# Fonction f1
# -----------
f1(x) =  2*(x[1] + x[2] + x[3] - 3)^2 + (x[1] - x[2])^2 + (x[2] - x[3])^2
# la gradient de la fonction f1
grad_f1(x) = [ 2 * (3 * x[1] + x[2] + 2 * x[3] - 6)
               2 * (x[1] + 4 * x[2] + x[3] -6)
               2 * (2*x[1] + x[2] + 3 * x[3] - 6)]
# la hessienne de la fonction f1
hess_f1(x) = [6 2 4
              2 8 2
              4 2 6]
sol_exacte = [1; 1; 1]
options = []

x0 = [1; 0; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("gct",f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats2("gradient conjugué tronqué","f1",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [10; 3; -2.2]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("gct",f1,grad_f1,hess_f1,x0,options)
t2 = time_ns()
my_afficher_resultats2("gradient conjugué tronqué","f1",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)


# Fonction f2
# -----------
f2(x) =  100*(x[2] - x[1]^2)^2 + (1 - x[1])^2
# la gradient de la fonction f2
grad_f2(x) = [2 * (200 * x[1]^3 -200 * x[1] * x[2] + x[1] - 1); 200 * (x[2] - x[1]^2)]
# la hessienne de la fonction f2

hess_f2(x) = [ (-400(x[2]-x[1]^2)+800*x[1]^2+2) (-400*x[1])
               (-400x[1])                       (200)]
sol_exacte = [1; 1]


x0 = [-1.2; 1]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("gradient conjugué tronqué","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [10; 0]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("gradient conjugué tronqué","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)

x0 = [0; 2e-3 + 1e-12]
t1 = time_ns()
xmin,f_min,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hess_f2,x0,options)
t2 = time_ns()
my_afficher_resultats2("gradient conjugué tronqué","f2",x0,xmin,f_min,flag,nb_iters, (t2-t1)/1e9)
# Out:
# -------------------------------------------------------------------------
# Résultats de : gradient conjugué tronqué appliqué à la quadratique q1:
#   * g = [0, 0]
#   * H = [7 0; 0 2]
#   * s = [0.0, 0.0]
# -------------------------------------------------------------------------
# Résultats de : gradient conjugué tronqué appliqué à la quadratique q2:
#   * g = [6, 2]
#   * H = [7 0; 0 2]
#   * s = [-0.8571428571428571, -0.9999999999999999]
# -------------------------------------------------------------------------
# Résultats de : gradient conjugué tronqué appliqué à la quadratique q3:
#   * g = [-2, 1]
#   * H = [-2 0; 0 10]
#   * s = [1.788854381999832, -0.894427190999916]
# -------------------------------------------------------------------------
# Résultats de : gradient conjugué tronqué appliqué à la quadratique q4:
#   * g = [0, 0]
#   * H = [-2 0; 0 10]
#   * s = [0.0, 0.0]
# -------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Interprétation
#
# 1. Comparer la décroissance obtenue avec celle du pas de Cauchy, en retournant, dans
# un premier temps le dernier itéré admissible à courbure positive (c’est à dire, que si
# l’une ou l’autre des deux conditions (b) ou (d) sont rencontrées dans l’algorithme 3,
# alors on ne calcule pas ``σ_{j}`` et on retourne le dernier itéré ``s_{j}`` directement).
#
# 2. Comparer la décroissance obtenue avec celle du pas de Cauchy, en imposant la sortie
# dans l’algorithme 3 au bout d’une itération seulement. Que remarquez vous ?
#
# 3. Comparer la décroissance obtenue avec celle du pas de Cauchy dans le cas général.
#
# 4. Quels sont les avantages et inconvénients des deux approches ?

# %% [markdown]
# ## Vos réponses?
# 1. L'algorithme du gct ne converge plus du tout pour certains points (la limite de 10 000 itérations étant atteinte).
# 2. On remarque qu'avec cette sortie, on obtient le pas de Cauchy. Ce qui signifie que l'algorithme du gradient conjugué tronqué est plus fin que celui du pas de cauchy. On s'attend donc à de meilleurs résultats en utilisant l'algorithme complet.
# 3. En effet, là où la convergence se comptait en milliers d'itération pour $f2$ avec le pas de cauchy, on a ici une convergence en une dizaine d'itérations. On remarque que l'algorithme converge toujours aussi vite sur $f1$, on peut en conclure que la méthode du gradient conjugué tronqué est significativement plus efficace que celle du pas de Cauchy.
# 4. A la vue des résultats ci-dessus, on peut estimer que l'algorithme du gradient conjugué tronqué converge en beaucoup moins d'itération que l'approche avec le pas de Cauchy. Si le problème est inconnu, il vaut mieux utiliser le gct. Cependant, une itération du pas de cauchy est moins coûteuse qu'une itération du gct, si les problèmes s'y prêtent, autant utiliser l'approche du pas de Cauchy. La mesure est évidemment approximative, mais on peut remarquer que selon le critère du temps d'execution, l'approche du pas de Cauchy est plus rapide sur f1.

# %% [markdown]
# # Lagrangien augmenté
#
# ## Implémentation
# 1.Choisir des critères d’arrêt pour la convergence de l'algorithme.
#
# 2.Implémenter l'algorithme du lagrangien augmenté, en utilisant les différentes méthodes
# qui ont été vues en première partie pour la résolution de la suite de problémes sans
# contraintes (fichier `Lagrangien_Augmente.jl`)
#
# 3.Tester les différentes variantes sur les problèmes en Annexe D.

# %%
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Lagrangien_Augmente.jl")

# Affichage les sorties de l'algorithme du gradient conjugué tronqué
function my_afficher_resultats(algo, f, xmin, fxmin, flag, niters, x0, time, lambda, mu)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de la méthode du langrangien augmenté version ",bold=true,color=:blue)
    printstyled(algo,bold=true,color=:red)
    printstyled(" appliqué à la fonction ",f, ":\n",bold=true,color=:blue)
    println("  * Point initial : ", x0)
    println("  * Solution : x = ", xmin)
    print("  * Valeur de la solution : ")
    printstyled("  * f(x) = ", fxmin, "\n", bold=true, color=:green)
    println("  * Nomre d'itérations : ", niters)
    println("  * Flag : ", flag)
    println("  * Temps d'execution : ", time, "s")
    println("  * Lambda et mu : ", lambda, ", ", mu)
end

print("-------------------------------------------------------------------------\nFonction f1\n")
# Fonction f1
# -----------
f1(x) =  2*(x[1] + x[2] + x[3] - 3)^2 + (x[1] - x[2])^2 + (x[2] - x[3])^2
# la gradient de la fonction f1
grad_f1(x) = [ 2 * (3 * x[1] + x[2] + 2 * x[3] - 6)
               2 * (x[1] + 4 * x[2] + x[3] -6)
               2 * (2*x[1] + x[2] + 3 * x[3] - 6)]
# la hessienne de la fonction f1
hess_f1(x) = [6 2 4
              2 8 2
              4 2 6]

# Contrainte
contrainte1(x) = x[1] + x[3] - 1
grad_contrainte1(x) = [1; 0; 1]
hess_contrainte1(x) = [0 0 0; 0 0 0; 0 0 0]

x11 = [0; 1; 1] # Realisable
x12 = [0.5; 1.25; 1] # Non réalisable
options = []

for x in [x11, x12]
    for algo in ["newton", "cauchy", "gct"]
        t1 = time_ns()
        xmin,fxmin,flag,iter,lambda,mu = Lagrangien_Augmente(algo, f1, contrainte1, grad_f1, hess_f1, grad_contrainte1, hess_contrainte1, x, options)
        t2 = time_ns()
        my_afficher_resultats(algo, "f1", xmin, fxmin, flag, iter, x, (t2-t1)/1e9,lambda,mu)
    end
end

print("\n\n-------------------------------------------------------------------------\nFonction f2\n")
# Fonction f2
# -----------
f2(x) =  100*(x[2] - x[1]^2)^2 + (1 - x[1])^2
# la gradient de la fonction f2
grad_f2(x) = [2 * (200 * x[1]^3 -200 * x[1] * x[2] + x[1] - 1); 200 * (x[2] - x[1]^2)]
# la hessienne de la fonction f2
hess_f2(x) = [ (-400(x[2]-x[1]^2)+800*x[1]^2+2) (-400*x[1])
               (-400x[1])                       (200)]
sol_exacte = [1; 1]

# Contrainte
contrainte2(x) = x[1]^2 + x[2]^2 - 1.5
grad_contrainte2(x) = [2 * x[1]; 2 * x[2]]
hess_contrainte2(x) = [2 2; 2 2]

x21 = [1; 0]
x22 = [sqrt(3)/2; sqrt(3)/2]
options = []

for x in [x21, x22]
    for algo in ["newton", "cauchy", "gct"]
        t1 = time_ns()
        xmin,fxmin,flag,iter,lambda,mu = Lagrangien_Augmente(algo, f2, contrainte2, grad_f2, hess_f2, grad_contrainte2, hess_contrainte2, x, options)
        t2 = time_ns()
        my_afficher_resultats(algo, "f2", xmin, fxmin, flag, iter, x, (t2-t1)/1e9,lambda,mu)
    end
end
# Out:
# -------------------------------------------------------------------------
# Fonction f1
# -------------------------------------------------------------------------
# Résultats de la méthode du langrangien augmenté version newton appliqué à la fonction f1:
#   * Point initial : [0.0, 1.0, 1.0]
#   * Solution : x = [0.5000000050482754, 1.2499999974758624, 0.5000000050482754]
#   * Valeur de la solution :   * f(x) = 2.249999954565523
#   * Nomre d'itérations : 6
#   * Flag : 0
#   * Temps d'execution : 0.142789101s
#   * Lambda et mu : 4.499999954565537, 200
# -------------------------------------------------------------------------
# Résultats de la méthode du langrangien augmenté version cauchy appliqué à la fonction f1:
#   * Point initial : [0.0, 1.0, 1.0]
#   * Solution : x = [0.4999999355623908, 1.2500000066012487, 0.500000066542295]
#   * Valeur de la solution :   * f(x) = 2.249999990528922
#   * Nomre d'itérations : 6
#   * Flag : 0
#   * Temps d'execution : 0.1526003s
# ...

# %% [markdown]
# ## Interprétation
#  1.Commenter les résultats obtenus, en étudiant notamment les valeurs de $\lambda_k$ et $\mu_k$.
#
#  2.Étudier l'influence du paramètre $\tau$ dans la performance de l'algorithme.
#
#  3.**Supplémentaire** :
#       Que proposez-vous comme méthode pour la résolution des problèmes avec
#       des contraintes à la fois d'égalité et d'inégalité ? Implémenter (si le temps le permet)
#       ce nouvel algorithme

# %% [markdown]
# ## Vos réponses?
# 1. Les résultats sont cohérents entre eux. On remarque cependant un valeur étonnante pour la version Newton sur $f2$ au point [1, 0]. La valeur de lambda y est négative, on a bien un point non rélisable pour cette algorithme, comme annoncé dans l'annexe.
# 2. $\tau$ est un paramètre qui influe sur la pénalité. Plus tau est grand, plus la pénalité en cas d'echec sera grande. On peu en soit le comparer avec $\gamma_2$ dans l'algorithme des régions de confiance. Plus on augmente $\tau$, plus les pénalités prendront de l'importance, et donc les solutions seront potentiellement trouvées plus vite, mais moins précises.
